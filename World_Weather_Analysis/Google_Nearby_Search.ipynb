# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config1 import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

# %%
len(hotels['results'])
# Out:
# 20

# %%
print(hotels)
# Out:
# {'html_attributions': [], 'next_page_token': 'Aap_uEAjFrn2b5x8Jg3R8-PBkvcwr44aVwoxLa3xow92VVarG9ztdjRcJi95NVP_EJ9zYRvE5fMDu0eSt7VLwZaC_cgMlnux3xF3KcGTyBpdv163Ur8pixtv2acWiP_cJobVB01qhdg2DRTuPelp2-BSq3einIOF3HBRO1qVvJdYavrnqNw0iMtp5lJevJDe-g5Jxb4_5c3xl4sa62EsQtCH1iQN4_rp8Q6vSubi7Dh0bzUOx0zB90b1oexcz-ypfmTNGXEweHGc_wXmtZle877ZwZedzB0aug-J6I3kNoefnC6WU5FW4xDZEIFyUBf9FbK92Op4d5puiObMmUaq6FFFSvTo1sBrJnRAOm-WeW0pq9Pmxf5qL4eUS94Fc2lEDGIZkbfKecNEfa_HsxCovpahntv7IsjF1qPeMlFIUcZ0nSTOFKs5fEiCjHxj', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277}, 'viewport': {'northeast': {'lat': 48.8594360302915, 'lng': 2.354355480291502}, 'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Hôtel Duo', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3840, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'], 'photo_reference': 'Aap_uEAD9SHsUqSjoe89BDVVFdwE-pBqoblgSA3TPuf_6FF8Zv63k-btl_9KmvJnzbPCrU6IhytALhYp0NfO6_JrdvMEzBV_PkTY03jOtZ5pqTr-XV9E_v0JURfFkASep6DvKTwEFRKEY6RuVYtSNlPFf8eAfTfAlmcTXAx9Sk7IWioq6v0F', 'width': 5760}], 'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc', 'plus_code': {'compound_code': 'V953+65 Paris, France', 'global_code': '8FW4V953+65'}, 'rating': 4.2, 'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc', 'scope': 'GOOGLE', 'types': ['night_club', 'spa', 'lodging', 'bar', 'gym', 'health', 'point_of_interest', 'establishment'], 'user_ratings_total': 324, 'vicinity': '11 Rue du Temple, Paris'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944}, 'viewport': {'northeast': {'lat': 48.85954748029151, 'lng': 2.347782830291502}, 'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Hôtel Britannique - Paris Centre', 'opening_hours': {'open_now': True}, 'photos': [{'height': 1426, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'], 'photo_reference': 'Aap_uEDXsCNjvztBra_1lC5yGnOW9CV5sJfPhKYHivgwruZ3J_qsfn4PFEoitTZcGOEIUT0IfInYcJCwryh1gUHTVGbB9k6G9UekOx_hUS-rbXNmqKffo_cPWxi0enSHeDAGSeaoJfPt0jaz7UP_XMZFXqOTMDqAQ21ctGpXivKPfEhqB3Bj', 'width': 1476}], 'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU', 'plus_code': {'compound_code': 'V85W+8H Paris, France', 'global_code': '8FW4V85W+8H'}, 'rating': 4.7, 'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 731, 'vicinity': '20 Avenue Victoria, Paris'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293}, 'viewport': {'northeast': {'lat': 48.8617746302915, 'lng': 2.347927730291502}, 'southwest': {'lat': 48.8590766697085, 'lng': 2.345229769708499}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Citadines Les Halles Paris', 'opening_hours': {'open_now': True}, 'photos': [{'height': 853, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'], 'photo_reference': 'Aap_uEDdi7lHT504J0EsckZecWjqOVOsHIjZFsXBitHgALi-gTichtqndngnOClh1GcRo-86jmC6iFaHKZpZJsKEvrH6B7ZgP7M_HkNUrJLppqSd2lt41UxzHiQXTzuy8Te2dtNZ0nLTviHiliI0ejj9Hhghi5pMiu5xhfxfAuj_M-wmsMrk', 'width': 1280}], 'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU', 'plus_code': ...

# %%
# How would you retrieve the name of the first hotel in the results dictionary?

hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'
